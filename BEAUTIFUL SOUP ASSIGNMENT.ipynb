# %%
#Please visit  https://www.keaipublishing.com/en/journals/artificial-intelligence-in-agriculture/most-downloaded
# articles/  and scrap- 
# a) Paper title 
# b)    date 
# c) Author

import requests
from bs4 import BeautifulSoup

# URL of the page you want to scrape
url = 'https://www.keaipublishing.com/en/journals/artificial-intelligence-in-agriculture/most-downloaded-articles/'

# Send an HTTP request to the URL
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    # Parse the page content
    soup = BeautifulSoup(response.content, 'html.parser')

    article_containers = soup.find_all('div', class_='panel') # Adjust class name here
    print("Total articles:",len(article_containers))
    
    for container in article_containers:
        # Extract title (adjust the tag and class based on your inspection)
        title = container.find('h2', class_='h5 article-title').get_text(strip=True) # Adjust tag and class
        
        # Extract date (adjust the tag and class based on your inspection)
        date = container.find('p', class_="article-date").text # Adjust tag and class
        
        # Extract authors (adjust the tag and class based on your inspection)
        authors = container.find('p', class_='article-authors').text # Adjust tag and class
        
        print(f'Title: {title}')
        print(f'Date: {date}')
        print(f'Authors: {authors}')
        print('-' * 40)
else:
    print(f'Failed to retrieve the webpage. Status code: {response.status_code}')
# Out:
# Total articles: 26
# Title: Implementation of artificial intelligence in agriculture for optimisation of irrigation and application of pesticides and herbicides
# Date: 2020
# Authors:  Tanha Talaviya |  Dhara Shah |  Nivedita Patel |  Hiteshri Yagnik |  Manan Shah
# ----------------------------------------
# Title: Review of agricultural IoT technology
# Date: 2022
# Authors:  Jinyuan Xu |  Baoxing Gu |  Guangzhao Tian
# ----------------------------------------
# Title: Automation and digitization of agriculture using artificial intelligence and internet of things
# Date: 2021
# Authors:  A. Subeesh |  C.R. Mehta
# ----------------------------------------
# Title: A comprehensive review on automation in agriculture using artificial intelligence
# Date: June 2019
# Authors:  Kirtan Jha |  Aalap Doshi |  Poojan Patel |  Manan Shah
# ----------------------------------------
# ...

# %%
#4) Write a python program to scrape first 10 product details which include product name , price , Image URL from 
#https://www.bewakoof.com/bestseller?sort=popular ...

import requests
from bs4 import BeautifulSoup

# URL of the page to scrape
url = 'https://www.bewakoof.com/bestseller?sort=popular'

# Send an HTTP request to the URL
response = requests.get(url)

soup = BeautifulSoup(response.content, 'html.parser')
product_containers = soup.find_all('div', class_='plp-product-card',limit=10)
  
for container in product_containers:
        # Extract the product name
        product_name = container.find('div', class_='productNaming bkf-ellipsis').get_text(strip=True)
          # Extract the product price
        product_price = container.find('div', class_='discountedPriceText clr-p-black false').get_text(strip=True)
        
        # Extract the image URL
        image_tag = container.find('img', class_='productImgTag')
        image_url = image_tag['src']
        
        print(f'Product Name: {product_name}')
        print(f'Discounted Price: {product_price}')
        print(f'Image URL: {image_url}')
        print('-' * 40)
# Out:
# Product Name: bewakoof x house of the dragonMen's Black House Of The Dragon Iconic Graphic Printed T-shirt
# Discounted Price: ₹399
# Image URL: https://images.bewakoof.com/t640/men-s-black-house-of-the-dragon-iconic-graphic-printed-t-shirt-519411-1715257899-1.jpg
# ----------------------------------------
# Product Name: Bewakoof®Women's White & Purple Camo Printed Oversized T-shirt
# Discounted Price: ₹439
# Image URL: https://images.bewakoof.com/t640/women-aop-oversize-t-shirt-12-580375-1684862463-1.jpg
# ----------------------------------------
# Product Name: bewakoof x tom & jerryWomen's Blue Moody Jerry Graphic Printed Oversized T-shirt
# Discounted Price: ₹499
# Image URL: https://images.bewakoof.com/t640/women-s-blue-moody-jerry-graphic-printed-oversized-t-shirt-585902-1715257595-1.jpg
# ----------------------------------------
# Product Name: Bewakoof®Men's Blue Rider Vroom Panda Graphic Printed T-shirt
# Discounted Price: ₹499
# ...

# %%
# Please visit https://www.cnbc.com/world/?region=world and scrap- 
# a)   headings 
# b)  date 
# c) News link 
import requests
from bs4 import BeautifulSoup

# URL of the page to scrape
url = 'https://www.cnbc.com/world/?region=world'

# Send an HTTP request to the URL
response = requests.get(url)

soup = BeautifulSoup(response.content, 'html.parser')

product_containers = soup.find_all('li',class_='LatestNews-item')
print ("Latest ",len(product_containers)," News")  

for container in product_containers:
        # Extract the product name
        heading = container.find('a', class_='LatestNews-headline').get_text(strip=True)
          # Extract the product price
        date = container.find('time', class_='LatestNews-timestamp').get_text(strip=True)
        
        # Extract the image URL
        news_tag = container.find('a', class_='LatestNews-headline')
        news_url=news_tag['href']
        
        print(f'Heading: {heading}')
        print(f'Date: {date}')
        print(f'News URL: {news_url}')
        print('-' * 40)
# Out:
# Latest  30  News
# Heading: Norfolk Southern board probing CEO Shaw over workplace relationship
# Date: 3 Hours Ago
# News URL: https://www.cnbc.com/2024/09/08/norfolk-southern-nsc-alan-shaw-workplace-relationship.html
# ----------------------------------------
# Heading: Here are the three most important things to watch in the market this week
# Date: 5 Hours Ago
# News URL: https://www.cnbc.com/2024/09/08/here-are-the-three-most-important-things-to-watch-in-the-market-this-week.html
# ----------------------------------------
# Heading: Bernie Sanders: Harris' 28% capital gains tax proposal should be higher
# Date: 6 Hours Ago
# News URL: https://www.cnbc.com/2024/09/08/bernie-sanders-harris-capital-gains-tax-trump-election.html
# ----------------------------------------
# Heading: Reddit CEO shares the daily habit that's helped him succeed the most
# Date: 8 Hours Ago
# ...

# %%
## Write a python program to scrape details of all the posts from https://www.patreon.com/coreyms .Scrape the 
## heading, date, content and the likes for the video from the link for the youtube video from the post.


import requests
from bs4 import BeautifulSoup

# Define the base URL
url = 'https://www.patreon.com/coreyms'


    
    # Send an HTTP request to the URL
response = requests.get(url)
    
    
soup = BeautifulSoup(response.content, 'html.parser')

posts = soup.find_all('div', class_='sc-137kp8k-1 lbjiyO')
print (len(posts)) 

# Find all post containers
   
    
    for post in posts:
        # Extract heading (title of the post)
        heading_tag = post.find('h2', class_='PostTitle')
        heading = heading_tag.get_text(strip=True) if heading_tag else 'No heading found'
        
        # Extract date of the post
        date_t
# Out:
#   Cell In[95], line 23
#     posts = soup.find_all('article', class_='Post')
#     ^
# IndentationError: unexpected indent
